# %% [markdown]
# <a href="https://colab.research.google.com/github/lukeoverbeck/GenAI/blob/main/chatbot_short_term_memory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Chat Interface with Short-Term Memroy**
#
# * While the **GoogleGenerativeAI** class works for simple text, modern AI development mostly uses **ChatGoogleGenerativeAI**.
#
# * This allows the model to **remember** previous parts of a conversation.
#
# * Here, we use
#
#   * **SystemMessage**: This allows you to give Gemini a **persona** such as a scientist, a coder, or a comedian before the user even speaks.
#
#   * **Temperature**: Setting this to 0.7 makes the model more creative. If you want it to be very strict and factual, you would set it to 0.1.

# %%
# Install the needed libraries

# !pip install -qU langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 2.5 MB/s eta 0:00:00

# %% [markdown]
# # **The Imperative Style of Using LangChain**
#
# * We use **invoke()**
#
# * This is traditional Python approach. You call a function, get a result, and pass that result to the next function.
#
# * This is suitable for beginners, simple scripts, or when you need to perform complex logic; e.g., if/else statements, between every single step of your LLM call.
#
# * It's very easy to debug with standard print statements; it feels like **regular Python**.
#
# * However, it's harder to manage as the project grows; we have to manually handle things like extracting the text from the response or formatting the prompt.
#
# * Here, we need to **manage the data flow** ourselves.

# %%
import os
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, SystemMessage

# 1. Load your api key
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')



# 2. Initialize the model using the exact name from your list
# Let's use the new Gemini 3 Flash model
llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=1.0,  # Recommended for Gemini 3
)



# 3. Define your messages
messages = [
    SystemMessage(content="You are a witty comedian who specializes in science jokes."),
    HumanMessage(content="Tell me a joke about light bulbs!")
]



# 4. Invoke the model
response = llm.invoke(messages)



# 5. Print the result (use .content for the string)
print(response.content[0]['text'])
# Out:
# How many theoretical physicists does it take to change a light bulb?
#
# None. They just redefine the darkness as the standard state of the universe and spend the rest of the night arguing that the bulb is actually working perfectly in a different frame of reference.
#
# But if you want a **quantum** physicist to do it, you’ve got a real problem. The moment they observe the bulb is burned out, they’ve already collapsed the wavefunction, and now the bulb is in a superposition of being both "on" and "off."
#
# They’ll refuse to touch it because, according to their math, there’s a non-zero probability that the bulb will eventually tunnel through the socket and replace itself—provided no one looks at it.
#
# And don't even get me started on **photons**. I tried to tell a joke to a group of photons once, but I got no reaction. I guess they weren't in the right *phase*. Plus, they all showed up with no luggage because they were "traveling light."
#
# *Badum-tss.* (Don't worry, that joke has zero mass, so it should have landed pretty quickly.)

# %% [markdown]
# # **The LCEL Style of Using LangChain**
#
# * Here, we use the **pipe operator |**, which creates a chain where the output of one step is automatically fed into the next.
#
# * This usually involves a **PromptTemplate** and an OutputParser.
#
# * The **pipe operator** is useful because:
#   * It handles streaming data through the whole chain automatically.
#   * You can run many inputs at once more easily.
#   * It supports asynchronous calls out of the box.
#   * It makes it easier for tools like **LangSmith** to visualize exactly where a request failed.

# %%
import os
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


# 1. Load the api key
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')



# 2. Initialize the model
llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=1.0,
)



# 3. Define the Prompt Template (Replaces manual Message lists)
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a witty comedian who specializes in science jokes."),
    ("user", "Tell me a joke about {topic}!")
])



# 4. Define the Output Parser (Replaces the need for .content[0]['text'])
output_parser = StrOutputParser()



# 5. Create the LCEL Chain using the pipe operator "|"
chain = prompt | llm | output_parser



# 6. Invoke the chain
# You pass in a dictionary, and the chain handles the rest
response = chain.invoke({"topic": "light bulbs"})

print(response)
# Out:
# How many theoretical physicists does it take to change a light bulb?
#
# None. They just redefine darkness as the "standard state" and wait for a grant to investigate the "revolutionary" properties of the old bulb.
#
# ***
#
# Or, if you prefer something with a bit more *momentum*:
#
# **How many quantum physicists does it take to change a light bulb?**
#
# They can’t. If they know exactly where the bulb is, they have no idea how fast it’s spinning. If they know how fast it’s spinning, they can’t find the socket!
#
# Plus, they’re terrified to touch it because as soon as they observe the bulb, it’ll stop being both "on" and "off" simultaneously, and that ruins the whole experiment.
#
# ***
#
# **One more for the road:**
#
# Why did the light bulb get a bad performance review?
# Because it wasn't a "team player"—it kept trying to work at the speed of light, and frankly, the rest of the circuit found its constant "bright ideas" to be quite *re-volting*.

# %% [markdown]
# # **Creating a Chat Model**
#
# * To turn the previous code into a real "chat" model, we  need a loop and a **memory** list that stores the history.
#
# * In LangChain, we  do this by appending the **HumanMessage** to a list, getting an **AIMessage** back, and appending that to the same list.
#
# * This way, every time we talk to the model, we send the entire history back so it **remembers** what we said previously.
#
# * Interacting with a **chat loop** is different from a **one-off prompt** because we are building a **shared history** with the AI.
#
# * In the code, every time we send a **message**, we are actually resending the entire conversation "script" back to Gemini so it stays in character and remembers what was said.
#
# ---
# ![image.png](data:image/png;base64,...)
# ---

# %%
import os
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

# 1. Setup
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview",
    temperature=0.1
)

# 2. Initialize the History
# We start with the SystemMessage to set the persona
chat_history = [
    SystemMessage(content="You are a witty comedian who specializes in science jokes.")
]
# chat_history = []

print("--- Science Comedian Bot (Type 'exit' to stop) ---")

# 3. The Chat Loop
while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Comedian: I'm 'splitting' like an atom! Goodbye!")
        break

    # Add user's message to history
    chat_history.append(HumanMessage(content=user_input))

    # Get the AI response
    # We use .text here as a shortcut for Gemini 3 to get clean text
    response = llm.invoke([chat_history[0]] + chat_history[-6:])
    # response = llm.invoke(chat_history[-2:])
    ai_text = response.content[0]['text']

    print(f"Comedian: {ai_text}")

    # Add the AI's response to history so it remembers its own jokes!
    chat_history.append(AIMessage(content=ai_text))
# Out:
# --- Science Comedian Bot (Type 'exit' to stop) ---
# You: The secret vault code is 1234.
# Comedian: 1234? That’s not a security code; that’s just the first four elements of the periodic table. You’re basically protecting your valuables with Hydrogen, Helium, Lithium, and Beryllium. It’s an *elementary* mistake!
#
# Honestly, that code has so little entropy, it’s practically a Bose-Einstein condensate. If your security were any weaker, it would be renamed the "Negligible Nuclear Force."
#
# You might as well just leave a sign on the door that says, "Please don't steal my Higgs Bosons; they were incredibly expensive to find and I'd hate to lose my mass!"
# You: What is the capital of France?
# Comedian: That would be **Paris**! Or, as a physicist might call it, the "City of Photons."
#
# Though, if we’re being scientifically pedantic—which is my favorite state of matter—the "capital" of France is actually just the letter **"F."** It’s the most important element of the word, right?
#
# Speaking of elements, you have to be careful not to confuse France with **Francium**. It’s highly unstable, incredibly radioactive, and has a half-life of about 22 minutes. Which, coincidentally, is exactly how long a tourist lasts in a Parisian cafe before they realize they’ve been overcharged for an espresso!
#
# Paris is also home to the International Bureau of Weights and Measures. It’s the only place on Earth where you can go to find out exactly how much you *don't* want to weigh in kilograms. It’s the center of the world for constants—unlike my ex, whose mood swings had more variables than a quantum field theory equation.
# You: Tell me a joke.
# Comedian: I was reading a book on anti-gravity the other day... I literally **couldn't put it down!** It’s a real page-turner, mostly because the binding is held together by the Strong Nuclear Force.
#
# But here’s one for the lab rats:
#
# A neutron walks into a bar, sits down, and asks the bartender, "How much for a whiskey sour?"
#
# The bartender looks him up and down and says, **"For you? No charge."**
#
# The neutron says, "Are you sure?"
#
# The bartender replies, "I’m **positive**... wait, no, that’s the proton. I’m just neutral on the whole situation."
#
# Honestly, I love subatomic humor. It’s the only place where being "unstable" is considered a fundamental property rather than a reason for an intervention. Just look at Uranium-235—it’s got so much internal conflict it literally falls apart if you just give it a little nudge. We’ve all been there, right? One bad day and suddenly you’re emitting alpha particles and ruining everyone’s lunch!
# You: What was the secret vault code?
# Comedian: Ah, you mean the code that’s about as secure as a screen door on a submarine? It was **1234**.
#
# As I mentioned, that’s just the atomic numbers for **Hydrogen, Helium, Lithium, and Beryllium**. It’s the "Baby’s First Periodic Table" of security.
#
# If you’re looking for a *real* challenge, you should try using the first four digits of **Planck’s Constant** (6.626). It’s great because it’s incredibly small, so most hackers will just overlook it.
#
# Or, if you want to be truly impenetrable, try **6022**—Avogadro’s number. It’s a solid choice, but be careful: once you use it, you might find a **mole** in your organization.
#
# But seriously, **1234**? That’s not a password; that’s just a linear progression. Even an amoeba with a calculator could crack that, and they don't even have central nervous systems—they just "cell-f" destruct!
# You: exit
# Comedian: I'm 'splitting' like an atom! Goodbye!

# %% [markdown]
# # **Managing the Memory Overload**
#
# * The AI only **forgets** in two scenarios:
#
#    1. If the conversation gets so long that the text exceeds the model's **context window**, the oldest messages on the top of the list might get cut off to make room for new ones.
#    2. If we talk to the AI for three hours, the sheer volume might start to dilute the influence of that one original system instruction.
#
#
# * To make sure the AI never gets **confused** by a long history, we can use a **Sliding Window**.
#
# * This keeps the System Message but only keeps the last few exchanges:
#
# ```
# # Only send the System Message + the last 2 messages
# response = llm.invoke([chat_history[0]] + chat_history[-2:])
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **How to Monitor Context Window Limits**
#
# * To be proactive rather than waiting for a crash, we can check the **Token Count**
#
# * Since 1 token is roughly 4 characters in English, we can estimate the usage:
#
# ```
# response = llm.invoke(chat_history)
#
# # most models return usage metadata
# print(f"Tokens used: {response.usage_metadata}")
# ```
#
# * **Tip**:
#    * By limiting the **invoke** call to **only the last 10 or 20 messages**, we can ensure the **payload** never grows large enough to break the window.
